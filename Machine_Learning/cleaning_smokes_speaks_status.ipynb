# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Raw data file
 
# read the dataset using the compression zip
df = pd.read_csv('../Okcupid.csv')
 
# display dataset
df.head()
# Out:
#    Unnamed: 0  age       body_type               diet    drinks      drugs  \
# 0           0   22  a little extra  strictly anything  socially      never
# 1           1   35         average       mostly other     often  sometimes
# 2           2   38            thin           anything  socially        NaN
# 3           3   23            thin         vegetarian  socially        NaN
# 4           4   29        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#    ...                         location  \
# ...

# %%
df1=df.drop(['Unnamed: 0'], axis = 1)

# %%
df1.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...                         location  \
# ...

# %%
df1['smokes'].value_counts()
# Out:
# no                43896
# sometimes          3787
# when drinking      3040
# yes                2231
# trying to quit     1480
# Name: smokes, dtype: int64

# %%
df1['speaks'].value_counts()
# Out:
# english                                                                21828
# english (fluently)                                                      6628
# english (fluently), spanish (poorly)                                    2059
# english (fluently), spanish (okay)                                      1917
# english (fluently), spanish (fluently)                                  1288
#                                                                        ...
# english (fluently), urdu (poorly), japanese (poorly), french (okay)        1
# english, spanish, hindi, c++                                               1
# english (fluently), japanese (okay), thai (okay), chinese (poorly)         1
# english (fluently), french (okay), italian (okay), hebrew (okay)           1
# english (fluently), french, farsi                                          1
# Name: speaks, Length: 7647, dtype: int64

# %%
#languages=df1['speaks'].value_counts()
languages=df['speaks'].value_counts().head(60)
languages
# Out:
# english                                                     21828
# english (fluently)                                           6628
# english (fluently), spanish (poorly)                         2059
# english (fluently), spanish (okay)                           1917
# english (fluently), spanish (fluently)                       1288
# english, spanish                                              859
# english (fluently), french (poorly)                           756
# english, spanish (okay)                                       655
# english, spanish (poorly)                                     609
# english (fluently), chinese (fluently)                        535
# english (fluently), french (okay)                             532
# english (fluently), chinese (okay)                            430
# english (poorly)                                              310
# english, chinese                                              306
# ...

# %%
df1['status'].value_counts()
# Out:
# single            55697
# seeing someone     2064
# available          1865
# married             310
# unknown              10
# Name: status, dtype: int64

# %%
spec_chars = ["(",")", "fluently", "poorly", "okay"]
for char in spec_chars:
    df['speaks'] = df['speaks'].str.replace(char, ' ')
    
df['speaks']
# Out:
# /var/folders/ng/g2rw737s09b_hmsyrmqzpq300000gn/T/ipykernel_66425/1130529553.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['speaks'] = df['speaks'].str.replace(char, ' ')
# 0                                                  english
# 1                     english    , spanish    , french
# 2                                     english, french, c++
# 3                                      english, german
# 4                                                  english
#                                ...
# 59941                                              english
# 59942                                          english
# 59943                                          english
# 59944    english    , spanish    , chinese    , korean ...
# 59945                                              english
# ...

# %%
#languages = df1.speaks.str.split(",")
#languages
#languages_cleaned=languages.str.get(1)
#languages_cleaned
#sns.countplot(data=df1, x="languages");

# %%
english=pd.DataFrame(df1[(df1.speaks == 'english') | (df1.speaks == 'english (fluently)')])
english.head()

#movies[(movies.duration >= 200) & (movies.genre == 'Drama')]
# Out:
#    age       body_type               diet      drinks  drugs  \
# 0   22  a little extra  strictly anything    socially  never
# 4   29        athletic                NaN    socially  never
# 6   32             fit  strictly anything    socially  never
# 8   24             NaN  strictly anything    socially    NaN
# 9   37        athletic    mostly anything  not at all  never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 4  graduated from college/university  asian, black, other    66.0      -1
# 6  graduated from college/university         white, other    65.0      -1
# 8  graduated from college/university                white    67.0      -1
# 9        working on two-year college                white    65.0      -1
#
#                            job  ...                         location  \
# 0               transportation  ...  south san francisco, california
# ...

# %%
#filter_list = ['spanish (fluently)', 'spanish (poorly)', 'spanish (okay)']
df1[['1', '2', '3']]=df1.speaks.str.split(",", n=2, expand=True)

# %%
df1
# Out:
#        age       body_type               diet      drinks      drugs  \
# 0       22  a little extra  strictly anything    socially      never
# 1       35         average       mostly other       often  sometimes
# 2       38            thin           anything    socially        NaN
# 3       23            thin         vegetarian    socially        NaN
# 4       29        athletic                NaN    socially      never
# ...    ...             ...                ...         ...        ...
# 59941   59             NaN                NaN    socially      never
# 59942   24             fit    mostly anything       often  sometimes
# 59943   42         average    mostly anything  not at all      never
# 59944   27        athletic    mostly anything    socially      often
# 59945   39         average                NaN    socially        NaN
#
#                                education            ethnicity  height  income  \
# ...

# %%
language_df = df1.astype(object).replace(np.nan, 'None')


language_df
# Out:
#        age       body_type               diet      drinks      drugs  \
# 0       22  a little extra  strictly anything    socially      never
# 1       35         average       mostly other       often  sometimes
# 2       38            thin           anything    socially       None
# 3       23            thin         vegetarian    socially       None
# 4       29        athletic               None    socially      never
# ...    ...             ...                ...         ...        ...
# 59941   59            None               None    socially      never
# 59942   24             fit    mostly anything       often  sometimes
# 59943   42         average    mostly anything  not at all      never
# 59944   27        athletic    mostly anything    socially      often
# 59945   39         average               None    socially       None
#
#                                education            ethnicity height  income  \
# ...
